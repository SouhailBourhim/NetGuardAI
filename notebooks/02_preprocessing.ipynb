# %% [markdown]
# # NetGuardAI — Preprocessing walkthrough
# Runs `src/preprocess.py` and inspects outputs.

# %%
import sys
sys.path.insert(0, '../src')
import preprocess
preprocess.run()
# Out:
# 2026-05-20 13:13:27,163  INFO  Loading 8 CSV files …
# 2026-05-20 13:13:29,118  INFO    Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv                   rows=225745
# 2026-05-20 13:13:31,184  INFO    Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv               rows=286467
# 2026-05-20 13:13:32,683  INFO    Friday-WorkingHours-Morning.pcap_ISCX.csv                          rows=191033
# 2026-05-20 13:13:37,594  INFO    Monday-WorkingHours.pcap_ISCX.csv                                  rows=529918
# 2026-05-20 13:13:39,755  INFO    Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv        rows=288602
# 2026-05-20 13:13:41,170  INFO    Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv             rows=170366
# 2026-05-20 13:13:45,008  INFO    Tuesday-WorkingHours.pcap_ISCX.csv                                 rows=445909
# 2026-05-20 13:13:53,301  INFO    Wednesday-workingHours.pcap_ISCX.csv                               rows=692703
# 2026-05-20 13:13:54,685  INFO  Combined shape: (2830743, 79)
# 2026-05-20 13:14:10,962  INFO  Dropped 308381 duplicate rows
# 2026-05-20 13:14:15,723  INFO  Dropped 1564 rows with NaN/inf values
# 2026-05-20 13:14:19,970  INFO  Dropping 8 constant features: ['Bwd PSH Flags', 'Bwd URG Flags', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate']
# 2026-05-20 13:14:58,297  INFO  Dropping 23 highly-correlated features (threshold=0.95): ['Total Backward Packets', 'Total Length of Bwd Packets', 'Fwd Packet Length Std', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Fwd IAT Total', 'Fwd IAT Max', 'Fwd Packets/s', 'Packet Length Std', 'SYN Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size', 'Fwd Header Length.1', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Idle Mean', 'Idle Max', 'Idle Min']
# 2026-05-20 13:14:58,307  INFO  Features retained after filtering: 47
# 2026-05-20 13:15:00,710  INFO  Train size: 2016638  |  Test size: 504160
# 2026-05-20 13:15:04,187  INFO  Class distribution before SMOTE (binary): {np.int64(0): np.int64(1758088), np.int64(1): np.int64(258550)}
# 2026-05-20 13:16:30,340  INFO  After SMOTE (binary): 2016638 → 3516176 samples
# 2026-05-20 13:16:30,374  INFO  Class distribution before SMOTE (multi): {np.int64(0): np.int64(1758088), np.int64(1): np.int64(1948), np.int64(2): np.int64(128014), np.int64(4): np.int64(15952), np.int64(5): np.int64(5228), np.int64(6): np.int64(5385), np.int64(7): np.int64(5931), np.int64(9): np.int64(36), np.int64(10): np.int64(90694), np.int64(11): np.int64(3219), np.int64(12): np.int64(1470), np.int64(13): np.int64(21), np.int64(14): np.int64(652)}
# 2026-05-20 13:18:39,314  INFO  After SMOTE (multi): 2016638 → 22855144 samples
# 2026-05-20 13:18:49,117  INFO  Saved X_train.npy                          shape=(3516176, 47)
# 2026-05-20 13:18:49,845  INFO  Saved X_test.npy                           shape=(504160, 47)
# 2026-05-20 13:18:50,046  INFO  Saved y_train_binary.npy                   shape=(3516176,)
# 2026-05-20 13:18:50,109  INFO  Saved y_test_binary.npy                    shape=(504160,)
# 2026-05-20 13:19:42,978  INFO  Saved X_train_multi.npy                    shape=(22855144, 47)
# 2026-05-20 13:19:43,690  INFO  Saved y_train_multi.npy                    shape=(22855144,)
# 2026-05-20 13:19:43,733  INFO  Saved y_test_multi.npy                     shape=(504160,)
# 2026-05-20 13:19:46,340  INFO  Saved X_train_scaled.npy                   shape=(2016638, 47)
# 2026-05-20 13:19:46,371  INFO  Saved y_train_binary_raw.npy               shape=(2016638,)
# 2026-05-20 13:19:46,430  INFO  Saved scaler.pkl                           shape=—
# 2026-05-20 13:19:46,441  INFO  Saved label_encoder.pkl                    shape=—
# 2026-05-20 13:19:46,459  INFO  Saved feature_cols.pkl                     shape=—
# 2026-05-20 13:19:46,463  INFO  Preprocessing complete. Artifacts saved to /Users/apple/Desktop/NetGuardAI/data/processed

# %%
import numpy as np, pickle
from pathlib import Path

PROC = Path('../data/processed')

X_train       = np.load(PROC / 'X_train.npy')
X_test        = np.load(PROC / 'X_test.npy')
y_train_bin   = np.load(PROC / 'y_train_binary.npy')
y_test_bin    = np.load(PROC / 'y_test_binary.npy')
y_train_multi = np.load(PROC / 'y_train_multi.npy')
y_test_multi  = np.load(PROC / 'y_test_multi.npy')

with open(PROC / 'label_encoder.pkl', 'rb') as f:
    le = pickle.load(f)
with open(PROC / 'feature_cols.pkl', 'rb') as f:
    feature_cols = pickle.load(f)

print(f'X_train : {X_train.shape}')
print(f'X_test  : {X_test.shape}')
print(f'y_train_binary  unique: {dict(zip(*np.unique(y_train_bin, return_counts=True)))}')
print(f'y_test_binary   unique: {dict(zip(*np.unique(y_test_bin, return_counts=True)))}')
print(f'Features retained: {len(feature_cols)}')
print(f'Label classes: {list(le.classes_)}')
# Out:
# X_train : (3516176, 47)
# X_test  : (504160, 47)
# y_train_binary  unique: {np.int64(0): np.int64(1758088), np.int64(1): np.int64(1758088)}
# y_test_binary   unique: {np.int64(0): np.int64(336969), np.int64(1): np.int64(167191)}
# Features retained: 47
# Label classes: ['BENIGN', 'Bot', 'DDoS', 'DoS GoldenEye', 'DoS Hulk', 'DoS Slowhttptest', 'DoS slowloris', 'FTP-Patator', 'Heartbleed', 'Infiltration', 'PortScan', 'SSH-Patator', 'Web Attack � Brute Force', 'Web Attack � Sql Injection', 'Web Attack � XSS']
